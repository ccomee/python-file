# %%
import cobra
from cobra import Reaction, Metabolite, Model
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Load Model

# %%
model = cobra.io.load_json_model('data/SI3_iJN1411final_flux_w_rhamnolipid_biosynthesis.json')

# %%
model.objective = model.reactions.BiomassKT2440_WT3.flux_expression
model.reactions.EX_glyc_e_.lower_bound = 0

# %% [markdown]
# # Biomass optimization for different carbon nutrients

# %%
non_carbon_nutrients_EX = ['EX_nh4_e_',      # ammonium
                           'EX_pi_e_',       # phosphate
                           'EX_so4_e_',      # sulfate
                           'EX_fe3_e_',      # fe3+
                           'EX_mn2_e_',      # mn2+
                           'EX_zn2_e_',      # zn2+
                           'EX_cu2_e_',      # cu2+
                           'EX_ca2_e_',      # ca2+
                           'EX_cl_e_',       # cl-
                           'EX_cobalt2_e_',  # cobalt
                           'EX_k_e_',        # k
                           'EX_mobd_e_',     # mo6+
                           'EX_na1_e_',      # na+
                           'EX_ni2_e_',      # ni2+
                           'EX_mg2_e_',      # mg2+
                           'EX_o2_e_']

carbon_nutrients_EX = []
for rea in model.reactions :
    if rea.id[:2] == 'EX' :
        if not(rea.id in non_carbon_nutrients_EX) :
            carbon_nutrients_EX.append(rea.id)

# %%
lb = -10

solutions = {nutrient:0 for nutrient in carbon_nutrients_EX}
for nutrient in carbon_nutrients_EX :
    model.reactions.get_by_id(nutrient).lower_bound = lb
    solutions[nutrient] = model.slim_optimize()
    model.reactions.get_by_id(nutrient).lower_bound = 0

# %%
solutions
# Out:
# {'EX_12dgr160_e_': 7.335881884101179,
#  'EX_12dgr180_e_': 8.216233488476776,
#  'EX_13dampp_e_': 0.4542690764921734,
#  'EX_15dap_e_': 0.9671021778962068,
#  'EX_1ag160_e_': 3.9795413924192538,
#  'EX_1ag180_e_': 4.419717194607067,
#  'EX_1ag181d9_e_': 4.37569961438832,
#  'EX_1ag182d9d12_e_': 4.295617659374216,
#  'EX_25dkglcn_e_': 0.7473203546858943,
#  'EX_26dap_M_e_': 0.8851189224251086,
#  'EX_2ameph_e_': 0.4324419342267242,
#  'EX_2ddglcn_e_': nan,
#  'EX_2dhglcn_e_': 0.8716003311852611,
#  'EX_2m35mdntha_e_': nan,
#  'EX_34dhbz_e_': 0.8369631737266482,
#  'EX_34dhcinm_e_': 1.2212726326322312,
#  'EX_34dhphe_e_': nan,
#  'EX_35dnta_e_': nan,
#  'EX_3h4atb_e_': nan,
#  'EX_3mb_e_': 0.8493126827335042,
#  'EX_3oxoadp_e_': 0.7434574863801573,
#  'EX_4abut_e_': 0.649951799033728,
#  'EX_4hbz_e_': 0.7496911988691674,
#  'EX_4hpro_DC_e_': 0.6873540739723836,
#  'EX_4hpro_LT_e_': 0.6873540739723839,
#  'EX_5aptn_e_': 0.8025927677347353,
#  'EX_5mcsn_e_': 0.2792872630314229,
#  'EX_5oxpro_e_': 0.5190438367484996,
#  'EX_6atha_e_': 0.42589125847322257,
#  'EX_6hnac_e_': 0.32267639921625824,
#  'EX_D_met_e_': 0.6049940946181938,
#  'EX_LalaLglu_e_': 1.0115071234406046,
#  'EX_Ncbmpts_e_': 0.5983180364260001,
#  'EX_R3hdec4e_e_': 1.9203554831448486,
#  'EX_R_3h4atba_e_': nan,
#  'EX_btn_e_': nan,
#  'EX_butso3_e_': nan,
#  'EX_bz_e_': 0.8502544237424536,
#  'EX_carn_e_': 0.9507293223661671,
#  'EX_catechol_e_': 0.8689903646797673,
#  'EX_cbi_e_': nan,
#  'EX_cbl1_e_': nan,
#  'EX_cd2_e_': nan,
#  'EX_cell4_e_': nan,
#  'EX_cgly_e_': 0.4535195652681464,
#  'EX_chol_e_': 0.892667940580794,
#  'EX_chols_e_': 0.47963699048701547,
#  'EX_chor_e_': 1.2961691140330447,
#  'EX_cinnm_e_': nan,
#  'EX_cit_e_': 0.5128101242587291,
#  'EX_cm_e_': nan,
#  'EX_cmcbtt_e_': nan,
#  'EX_co2_e_': nan,
#  'EX_co_e_': nan,
#  'EX_confrl_e_': 1.4400759565236347,
#  'EX_creat_e_': 0.30901898789177573,
#  'EX_crn_e_': 1.0890288859783193,
#  'EX_cro2_e_': nan,
#  'EX_cro4_e_': nan,
#  'EX_crtn_e_': 0.010150758489644168,
#  'EX_csn_e_': nan,
#  'EX_cu_e_': nan,
#  'EX_cyan_e_': nan,
#  'EX_cys_D_e_': 0.2950962005512491,
#  'EX_cys_L_e_': 0.2950962005512466,
#  'EX_dag181d9_e_': 8.128198328039247,
#  'EX_dag182d9d12_e_': 7.968476765210351,
#  'EX_dca_e_': 2.030321324636968,
#  'EX_ddca_e_': 2.4712436118122185,
#  'EX_dgudbutn_e_': 0.7921725789498812,
#  'EX_dmanur_e_': nan,
#  'EX_dmgly_e_': 0.5218745589177984,
#  'EX_dmso2_e_': nan,
#  'EX_dopa_e_': nan,
#  'EX_ecto_L_e_': 0.830729461237183,
#  'EX_enter_e_': nan,
#  'EX_etha_e_': 0.3778847665053428,
#  'EX_ethso3_e_': nan,
#  'EX_etoh_e_': 0.4651762348595477,
#  'EX_fald_e_': 0.14556998554409786,
#  'EX_fcmcbtt_e_': nan,
#  'EX_fe2_e_': nan,
#  'EX_fe3dcit_e_': 1.0303124334300315,
#  'EX_fe3mcbtt_e_': nan,
#  'EX_fe3pyovd_e_': nan,
#  'EX_fe3pyovd_kt_e_': nan,
#  'EX_fecrm_e_': nan,
#  'EX_fecrm_un_e_': nan,
#  'EX_feenter_e_': nan,
#  'EX_feoxam_e_': nan,
#  'EX_feoxam_un_e_': nan,
#  'EX_fer_e_': 1.2978537959942125,
#  'EX_for_e_': nan,
#  'EX_fru_e_': 1.0501953627572334,
#  'EX_fum_e_': 0.3195650371266848,
#  'EX_ga_e_': 0.7870934738087623,
#  'EX_galct_D_e_': 0.6063158116115135,
#  'EX_galur_e_': 0.7834787356127534,
#  'EX_glc_e_': 0.9792626993773825,
#  'EX_glcn_e_': 0.9213123217849953,
#  'EX_glcr_e_': 0.6063158116062437,
#  'EX_glcur_e_': 0.7834787356153377,
#  'EX_gln_L_e_': 0.6063158116053214,
#  'EX_glu_L_e_': 0.6063158116053314,
#  'EX_glutar_e_': 0.5814170809818734,
#  'EX_gly_e_': 0.1434646548715397,
#  'EX_glyald_e_': 0.5230339003342375,
#  'EX_glyb_e_': 0.7229048204423816,
#  'EX_glyc_R_e_': 0.3836178846080941,
#  'EX_glyc_e_': 0.6015473096312863,
#  'EX_glyclt_e_': 0.09445338387734642,
#  'EX_glycol_e_': 0.2379600125950538,
#  'EX_glygln_e_': 0.7443142273525749,
#  'EX_glyglu_e_': 0.7434140590268444,
#  'EX_glygly_e_': 0.260467081788801,
#  'EX_glymet_e_': 0.7797019700139622,
#  'EX_glyphe_e_': 1.6130625078780747,
#  'EX_glyser_e_': 0.462964542057874,
#  'EX_gua_e_': nan,
#  'EX_gudac_e_': 0.09071233380431988,
#  'EX_gudptn_e_': 0.8025927677347321,
#  'EX_h2o2_e_': nan,
#  'EX_h2o_e_': nan,
#  'EX_h2s_e_': nan,
#  'EX_h_e_': nan,
#  'EX_hco3_e_': nan,
#  'EX_hcyst_L_e_': 0.43245602800814104,
#  'EX_hdca_e_': 3.3522908743017212,
#  'EX_hdcea_e_': 3.316100035799894,
#  'EX_hg2_e_': nan,
#  'EX_hgentis_e_': 1.0899906382973887,
#  'EX_his_L_e_': 0.5401342394595741,
#  'EX_hisgly_e_': 0.6580567045396142,
#  'EX_hishis_e_': 1.029981545535035,
#  'EX_hom_L_e_': 0.649951799033744,
#  'EX_hpa_e_': 1.3516546726483607,
#  'EX_hxa_e_': 1.1455890893566114,
#  'EX_hxan_e_': 0.04576662069096557,
#  'EX_icit_e_': 0.5128101242587302,
#  'EX_ile_L_e_': 1.1133712693675364,
#  'EX_ind3ac_e_': nan,
#  'EX_indole_e_': nan,
#  'EX_ins_e_': nan,
#  'EX_isetac_e_': nan,
#  'EX_lac_D_e_': 0.4125997273030337,
#  'EX_lac_L_e_': 0.3763346627914594,
#  'EX_leu_D_e_': 0.994635106061084,
#  'EX_leu_L_e_': 1.06683649200974,
#  'EX_leuleu_e_': 2.1148274616090466,
#  'EX_lnlc_e_': 3.6688123628692084,
#  'EX_lpspput_e_': nan,
#  'EX_lys_D_e_': 0.9745916390651682,
#  'EX_lys_L_e_': 0.9745916390669467,
#  'EX_m_xyl_e_': 1.1422359338173937,
#  'EX_mal_D_e_': nan,
#  'EX_mal_L_e_': 0.3195650370757519,
#  'EX_man_e_': 0.9684627015928552,
#  'EX_manur_e_': nan,
#  'EX_mcbtt_e_': nan,
#  'EX_meoh_e_': 0.2203198314073164,
#  'EX_met_L_e_': 0.604994094618191,
#  'EX_mmet_e_': 0.5767341280707302,
#  'EX_mso3_e_': nan,
#  'EX_nac_e_': 0.3227146660770015,
#  'EX_no2_e_': nan,
#  'EX_no3_e_': nan,
#  'EX_no_e_': nan,
#  'EX_nona_e_': 1.7925362280819697,
#  'EX_o_xyl_e_': nan,
#  'EX_oaa_e_': 0.2322930622188637,
#  'EX_ocdca_e_': 3.792466676489595,
#  'EX_ocdcea_e_': 3.7484490962707624,
#  'EX_octa_e_': 1.5869922420957545,
#  'EX_orn_D_e_': 0.7614468806049471,
#  'EX_orn_e_': 0.8441464399023365,
#  'EX_orot_e_': 0.010319152708831096,
#  'EX_oxa_e_': nan,
#  'EX_oxoarg_L_e_': 0.7015165386707584,
#  'EX_p_xyl_e_': 1.0981477782740408,
#  'EX_pac_e_': 1.2540931312159447,
#  'EX_pacald_e_': 1.2869136297996528,
#  'EX_pb2_e_': nan,
#  'EX_pea_e_': 1.308793962188794,
#  'EX_peamn_e_': 1.3087939621887885,
#  'EX_pentso3_e_': nan,
#  'EX_phe_D_e_': 1.3949945090440252,
#  'EX_phe_L_e_': 1.428305954592389,
#  'EX_phedca_e_': 3.004519722346768,
#  'EX_phehpa_e_': 0.8579878424533681,
#  'EX_phehxa_e_': 2.1293064267815454,
#  'EX_pheme_e_': nan,
#  'EX_phenona_e_': 1.2944451842244753,
#  'EX_pheocta_e_': 2.5669130745643263,
#  'EX_phept_e_': 0.4215305006824458,
#  'EX_phpyr_e_': 1.350579248062101,
#  'EX_pnto_R_e_': nan,
#  'EX_ppa_e_': 0.41259972730303385,
#  'EX_ppi_e_': nan,
#  'EX_prealg_MG_14__e_': nan,
#  'EX_prealg_MG_23__e_': nan,
#  'EX_prealg_MG_32__e_': nan,
#  'EX_prealg_MG_41__e_': nan,
#  'EX_prealginate_G__e_': nan,
#  'EX_pro_D_e_': 0.7614468806035557,
#  'EX_pro_L_e_': 0.8326855958100294,
#  'EX_progly_e_': 0.969488260115121,
#  'EX_pta_e_': 0.8961339207907069,
#  'EX_ptrc_e_': 0.8296082341778366,
#  'EX_ptsla_e_': 3.748449096271093,
#  'EX_pydam_e_': nan,
#  'EX_pyovd_e_': nan,
#  'EX_pyovd_kt_e_': nan,
#  'EX_pyr_e_': 0.3279812434426886,
#  'EX_quin_kt_e_': 0.9394478627856082,
#  'EX_rib_D_e_': 0.8063585965523984,
#  'EX_sbo3_e_': nan,
#  'EX_sel_e_': nan,
#  'EX_ser_D_e_': 0.34665098065639693,
#  'EX_ser_L_e_': 0.3332366303934995,
#  'EX_sheme_e_': nan,
#  'EX_skm_e_': 0.9394478627856033,
#  'EX_so2_e_': nan,
#  'EX_so3_e_': nan,
#  'EX_spmd_e_': 1.188462600641108,
#  'EX_succ_e_': 0.36943473699393836,
#  'EX_sulfac_e_': nan,
#  'EX_tag160_e_': 10.692222375783166,
#  'EX_tag180_e_': 12.01274978234628,
#  'EX_tag181d9_e_': 11.880697041689995,
#  'EX_tag182d9d12_e_': 11.641335871046595,
#  'EX_taur_e_': nan,
#  'EX_tcynt_e_': nan,
#  'EX_thr_L_e_': 0.5829540016912007,
#  'EX_thym_e_': 0.4130750577972045,
#  'EX_tmanur_e_': nan,
#  'EX_tnt_e_': nan,
#  'EX_tol_e_': 0.9463498691150942,
#  'EX_trp_L_e_': 0.046181319144955844,
#  'EX_tsul_e_': nan,
#  'EX_ttdca_e_': 2.912115072113934,
#  'EX_ttdcea_e_': 2.874882861872993,
#  'EX_ttrcyc_e_': nan,
#  'EX_tungs_e_': nan,
#  'EX_tyr_D_e_': 1.1443185302985288,
#  'EX_tyr_L_e_': 1.1774449351821399,
#  'EX_ura_e_': 0.14676273237725762,
#  'EX_urea_e_': nan,
#  'EX_uri_e_': 1.2404202128170096,
#  'EX_vacc_e_': 3.757317209726732,
#  'EX_val_D_e_': 0.7368753999951899,
#  'EX_val_L_e_': 0.8104011832718195,
#  'EX_vanln_e_': 1.002469308740845,
#  'EX_vanlt_e_': 0.9242351485837856,
#  'EX_xan_e_': nan,
#  'EX_haa_e_': nan,
#  'EX_lrhh_e_': nan,
#  'EX_llrhh_e_': nan}
